# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 227.0631 - y1_output_loss: 109.6587 - y2_output_loss: 115.3779 - y1_output_root_mean_squared_error: 10.5174 - y2_output_root_mean_squared_error: 10.7911 - val_loss: 40.2967 - val_y1_output_loss: 17.3254 - val_y2_output_loss: 22.8050 - val_y1_output_root_mean_squared_error: 4.1096 - val_y2_output_root_mean_squared_error: 4.8382
# Epoch 2/500
# 614/614 [==============================] - 0s 161us/sample - loss: 34.8880 - y1_output_loss: 13.1988 - y2_output_loss: 21.4995 - y1_output_root_mean_squared_error: 3.6467 - y2_output_root_mean_squared_error: 4.6464 - val_loss: 33.1474 - val_y1_output_loss: 9.5726 - val_y2_output_loss: 23.4584 - val_y1_output_root_mean_squared_error: 3.0828 - val_y2_output_root_mean_squared_error: 4.8625
# Epoch 3/500
# 614/614 [==============================] - 0s 130us/sample - loss: 27.2929 - y1_output_loss: 10.5173 - y2_output_loss: 16.5909 - y1_output_root_mean_squared_error: 3.2505 - y2_output_root_mean_squared_error: 4.0899 - val_loss: 24.2329 - val_y1_output_loss: 9.7931 - val_y2_output_loss: 14.3241 - val_y1_output_root_mean_squared_error: 3.0880 - val_y2_output_root_mean_squared_error: 3.8337
# Epoch 4/500
# 614/614 [==============================] - 0s 132us/sample - loss: 26.7967 - y1_output_loss: 10.1454 - y2_output_loss: 16.5537 - y1_output_root_mean_squared_error: 3.1947 - y2_output_root_mean_squared_error: 4.0731 - val_loss: 20.1009 - val_y1_output_loss: 7.6897 - val_y2_output_loss: 12.3312 - val_y1_output_root_mean_squared_error: 2.7300 - val_y2_output_root_mean_squared_error: 3.5564
# Epoch 5/500
# 614/614 [==============================] - 0s 142us/sample - loss: 27.0593 - y1_output_loss: 10.3854 - y2_output_loss: 16.6650 - y1_output_root_mean_squared_error: 3.2237 - y2_output_root_mean_squared_error: 4.0825 - val_loss: 29.4797 - val_y1_output_loss: 9.4302 - val_y2_output_loss: 19.8680 - val_y1_output_root_mean_squared_error: 3.0311 - val_y2_output_root_mean_squared_error: 4.5047
# Epoch 6/500
# 614/614 [==============================] - 0s 137us/sample - loss: 23.7122 - y1_output_loss: 9.5041 - y2_output_loss: 14.3338 - y1_output_root_mean_squared_error: 3.0811 - y2_output_root_mean_squared_error: 3.7708 - val_loss: 49.2684 - val_y1_output_loss: 10.3600 - val_y2_output_loss: 39.5939 - val_y1_output_root_mean_squared_error: 3.1779 - val_y2_output_root_mean_squared_error: 6.2585
# Epoch 7/500
# 614/614 [==============================] - 0s 139us/sample - loss: 27.7520 - y1_output_loss: 10.2179 - y2_output_loss: 17.3175 - y1_output_root_mean_squared_error: 3.2096 - y2_output_root_mean_squared_error: 4.1774 - val_loss: 18.7852 - val_y1_output_loss: 7.6419 - val_y2_output_loss: 11.0607 - val_y1_output_root_mean_squared_error: 2.7223 - val_y2_output_root_mean_squared_error: 3.3726
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 20.4328 - y1_output_loss: 8.3900 - y2_output_loss: 12.1018 - y1_output_root_mean_squared_error: 2.8943 - y2_output_root_mean_squared_error: 3.4721 - val_loss: 49.5731 - val_y1_output_loss: 9.9849 - val_y2_output_loss: 39.5975 - val_y1_output_root_mean_squared_error: 3.1771 - val_y2_output_root_mean_squared_error: 6.2833
# Epoch 9/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.5415 - y1_output_loss: 8.1870 - y2_output_loss: 12.2163 - y1_output_root_mean_squared_error: 2.8750 - y2_output_root_mean_squared_error: 3.5037 - val_loss: 20.7505 - val_y1_output_loss: 7.6785 - val_y2_output_loss: 13.0093 - val_y1_output_root_mean_squared_error: 2.7268 - val_y2_output_root_mean_squared_error: 3.6490
# Epoch 10/500
# 614/614 [==============================] - 0s 140us/sample - loss: 22.6390 - y1_output_loss: 8.6020 - y2_output_loss: 13.8294 - y1_output_root_mean_squared_error: 2.9462 - y2_output_root_mean_squared_error: 3.7361 - val_loss: 19.4313 - val_y1_output_loss: 7.0799 - val_y2_output_loss: 12.2812 - val_y1_output_root_mean_squared_error: 2.6184 - val_y2_output_root_mean_squared_error: 3.5462
# Epoch 11/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.3155 - y1_output_loss: 7.8269 - y2_output_loss: 12.4173 - y1_output_root_mean_squared_error: 2.8092 - y2_output_root_mean_squared_error: 3.5248 - val_loss: 17.8530 - val_y1_output_loss: 7.1953 - val_y2_output_loss: 10.5444 - val_y1_output_root_mean_squared_error: 2.6433 - val_y2_output_root_mean_squared_error: 3.2964
# Epoch 12/500
# 614/614 [==============================] - 0s 134us/sample - loss: 20.9249 - y1_output_loss: 8.1805 - y2_output_loss: 12.5533 - y1_output_root_mean_squared_error: 2.8724 - y2_output_root_mean_squared_error: 3.5601 - val_loss: 23.8238 - val_y1_output_loss: 7.9979 - val_y2_output_loss: 15.6742 - val_y1_output_root_mean_squared_error: 2.7895 - val_y2_output_root_mean_squared_error: 4.0053
# Epoch 13/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.1288 - y1_output_loss: 7.5767 - y2_output_loss: 11.5177 - y1_output_root_mean_squared_error: 2.7556 - y2_output_root_mean_squared_error: 3.3964 - val_loss: 22.4598 - val_y1_output_loss: 6.9601 - val_y2_output_loss: 15.2811 - val_y1_output_root_mean_squared_error: 2.6446 - val_y2_output_root_mean_squared_error: 3.9327
# Epoch 14/500
# 614/614 [==============================] - 0s 138us/sample - loss: 21.7493 - y1_output_loss: 8.4002 - y2_output_loss: 13.4248 - y1_output_root_mean_squared_error: 2.9021 - y2_output_root_mean_squared_error: 3.6506 - val_loss: 33.5041 - val_y1_output_loss: 7.3068 - val_y2_output_loss: 26.0764 - val_y1_output_root_mean_squared_error: 2.7301 - val_y2_output_root_mean_squared_error: 5.1040
# Epoch 15/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.6593 - y1_output_loss: 6.9659 - y2_output_loss: 9.8335 - y1_output_root_mean_squared_error: 2.6371 - y2_output_root_mean_squared_error: 3.1153 - val_loss: 35.1211 - val_y1_output_loss: 7.4862 - val_y2_output_loss: 27.8070 - val_y1_output_root_mean_squared_error: 2.7542 - val_y2_output_root_mean_squared_error: 5.2474
# Epoch 16/500
# 614/614 [==============================] - 0s 145us/sample - loss: 19.1645 - y1_output_loss: 7.1955 - y2_output_loss: 11.8905 - y1_output_root_mean_squared_error: 2.6777 - y2_output_root_mean_squared_error: 3.4633 - val_loss: 13.4555 - val_y1_output_loss: 5.1872 - val_y2_output_loss: 8.1099 - val_y1_output_root_mean_squared_error: 2.2638 - val_y2_output_root_mean_squared_error: 2.8863
# Epoch 17/500
# 614/614 [==============================] - 0s 137us/sample - loss: 20.0468 - y1_output_loss: 7.3323 - y2_output_loss: 12.6809 - y1_output_root_mean_squared_error: 2.7082 - y2_output_root_mean_squared_error: 3.5654 - val_loss: 14.1328 - val_y1_output_loss: 5.9222 - val_y2_output_loss: 8.0375 - val_y1_output_root_mean_squared_error: 2.4096 - val_y2_output_root_mean_squared_error: 2.8856
# Epoch 18/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.4070 - y1_output_loss: 7.0285 - y2_output_loss: 11.2931 - y1_output_root_mean_squared_error: 2.6587 - y2_output_root_mean_squared_error: 3.3672 - val_loss: 21.0860 - val_y1_output_loss: 6.3657 - val_y2_output_loss: 14.3998 - val_y1_output_root_mean_squared_error: 2.5112 - val_y2_output_root_mean_squared_error: 3.8444
# Epoch 19/500
# 614/614 [==============================] - 0s 145us/sample - loss: 16.6343 - y1_output_loss: 6.4037 - y2_output_loss: 10.2553 - y1_output_root_mean_squared_error: 2.5362 - y2_output_root_mean_squared_error: 3.1941 - val_loss: 19.9308 - val_y1_output_loss: 5.2822 - val_y2_output_loss: 14.4474 - val_y1_output_root_mean_squared_error: 2.3246 - val_y2_output_root_mean_squared_error: 3.8115
# Epoch 20/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.5062 - y1_output_loss: 7.6025 - y2_output_loss: 13.8619 - y1_output_root_mean_squared_error: 2.7465 - y2_output_root_mean_squared_error: 3.7367 - val_loss: 29.3203 - val_y1_output_loss: 8.6492 - val_y2_output_loss: 20.6814 - val_y1_output_root_mean_squared_error: 2.8933 - val_y2_output_root_mean_squared_error: 4.5770
# Epoch 21/500
# 614/614 [==============================] - 0s 139us/sample - loss: 14.5462 - y1_output_loss: 5.8104 - y2_output_loss: 8.6215 - y1_output_root_mean_squared_error: 2.4185 - y2_output_root_mean_squared_error: 2.9491 - val_loss: 12.2480 - val_y1_output_loss: 4.6294 - val_y2_output_loss: 7.3972 - val_y1_output_root_mean_squared_error: 2.1421 - val_y2_output_root_mean_squared_error: 2.7675
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.5143 - y1_output_loss: 6.0602 - y2_output_loss: 9.5308 - y1_output_root_mean_squared_error: 2.4354 - y2_output_root_mean_squared_error: 3.0957 - val_loss: 17.1071 - val_y1_output_loss: 5.7390 - val_y2_output_loss: 11.1642 - val_y1_output_root_mean_squared_error: 2.3805 - val_y2_output_root_mean_squared_error: 3.3824
# Epoch 23/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.8857 - y1_output_loss: 6.2730 - y2_output_loss: 10.5617 - y1_output_root_mean_squared_error: 2.5049 - y2_output_root_mean_squared_error: 3.2575 - val_loss: 20.7486 - val_y1_output_loss: 5.2344 - val_y2_output_loss: 15.3012 - val_y1_output_root_mean_squared_error: 2.2684 - val_y2_output_root_mean_squared_error: 3.9501
# Epoch 24/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.6533 - y1_output_loss: 5.4109 - y2_output_loss: 8.2541 - y1_output_root_mean_squared_error: 2.3137 - y2_output_root_mean_squared_error: 2.8810 - val_loss: 12.8310 - val_y1_output_loss: 4.4710 - val_y2_output_loss: 8.0528 - val_y1_output_root_mean_squared_error: 2.1338 - val_y2_output_root_mean_squared_error: 2.8771
# Epoch 25/500
# 614/614 [==============================] - 0s 136us/sample - loss: 14.7578 - y1_output_loss: 5.5501 - y2_output_loss: 9.0738 - y1_output_root_mean_squared_error: 2.3662 - y2_output_root_mean_squared_error: 3.0263 - val_loss: 18.5408 - val_y1_output_loss: 6.2559 - val_y2_output_loss: 12.0752 - val_y1_output_root_mean_squared_error: 2.4840 - val_y2_output_root_mean_squared_error: 3.5172
# Epoch 26/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.8324 - y1_output_loss: 5.5333 - y2_output_loss: 8.4026 - y1_output_root_mean_squared_error: 2.3412 - y2_output_root_mean_squared_error: 2.8899 - val_loss: 25.9796 - val_y1_output_loss: 7.0375 - val_y2_output_loss: 18.8185 - val_y1_output_root_mean_squared_error: 2.6722 - val_y2_output_root_mean_squared_error: 4.3404
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.1032 - y1_output_loss: 5.0924 - y2_output_loss: 8.0554 - y1_output_root_mean_squared_error: 2.2492 - y2_output_root_mean_squared_error: 2.8362 - val_loss: 21.5775 - val_y1_output_loss: 6.3014 - val_y2_output_loss: 15.4062 - val_y1_output_root_mean_squared_error: 2.5297 - val_y2_output_root_mean_squared_error: 3.8959
# Epoch 28/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.6376 - y1_output_loss: 4.7218 - y2_output_loss: 6.9244 - y1_output_root_mean_squared_error: 2.1738 - y2_output_root_mean_squared_error: 2.6291 - val_loss: 19.7821 - val_y1_output_loss: 6.8050 - val_y2_output_loss: 13.0375 - val_y1_output_root_mean_squared_error: 2.6271 - val_y2_output_root_mean_squared_error: 3.5889
# Epoch 29/500
# 614/614 [==============================] - 0s 140us/sample - loss: 14.5410 - y1_output_loss: 5.3195 - y2_output_loss: 9.1639 - y1_output_root_mean_squared_error: 2.3008 - y2_output_root_mean_squared_error: 3.0409 - val_loss: 21.5638 - val_y1_output_loss: 8.4205 - val_y2_output_loss: 12.9950 - val_y1_output_root_mean_squared_error: 2.8710 - val_y2_output_root_mean_squared_error: 3.6498
# Epoch 30/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.1398 - y1_output_loss: 4.6498 - y2_output_loss: 7.5106 - y1_output_root_mean_squared_error: 2.1538 - y2_output_root_mean_squared_error: 2.7388 - val_loss: 17.4163 - val_y1_output_loss: 5.2231 - val_y2_output_loss: 11.8478 - val_y1_output_root_mean_squared_error: 2.2796 - val_y2_output_root_mean_squared_error: 3.4956
# Epoch 31/500
# 614/614 [==============================] - 0s 126us/sample - loss: 13.2611 - y1_output_loss: 4.8816 - y2_output_loss: 8.4537 - y1_output_root_mean_squared_error: 2.2080 - y2_output_root_mean_squared_error: 2.8958 - val_loss: 11.0623 - val_y1_output_loss: 3.3526 - val_y2_output_loss: 7.5822 - val_y1_output_root_mean_squared_error: 1.8372 - val_y2_output_root_mean_squared_error: 2.7726
# Epoch 32/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.5037 - y1_output_loss: 4.3883 - y2_output_loss: 7.3172 - y1_output_root_mean_squared_error: 2.0713 - y2_output_root_mean_squared_error: 2.6858 - val_loss: 34.9401 - val_y1_output_loss: 10.2745 - val_y2_output_loss: 26.1703 - val_y1_output_root_mean_squared_error: 3.1564 - val_y2_output_root_mean_squared_error: 4.9977
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.6350 - y1_output_loss: 4.2800 - y2_output_loss: 8.2593 - y1_output_root_mean_squared_error: 2.0758 - y2_output_root_mean_squared_error: 2.8855 - val_loss: 8.9931 - val_y1_output_loss: 2.9820 - val_y2_output_loss: 5.7594 - val_y1_output_root_mean_squared_error: 1.7424 - val_y2_output_root_mean_squared_error: 2.4407
# Epoch 34/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.5418 - y1_output_loss: 4.4620 - y2_output_loss: 7.9830 - y1_output_root_mean_squared_error: 2.1221 - y2_output_root_mean_squared_error: 2.8353 - val_loss: 14.1745 - val_y1_output_loss: 4.1481 - val_y2_output_loss: 10.0090 - val_y1_output_root_mean_squared_error: 2.0524 - val_y2_output_root_mean_squared_error: 3.1563
# Epoch 35/500
# 614/614 [==============================] - 0s 149us/sample - loss: 11.2199 - y1_output_loss: 4.1002 - y2_output_loss: 7.3566 - y1_output_root_mean_squared_error: 2.0128 - y2_output_root_mean_squared_error: 2.6774 - val_loss: 17.7129 - val_y1_output_loss: 4.6478 - val_y2_output_loss: 13.2450 - val_y1_output_root_mean_squared_error: 2.1622 - val_y2_output_root_mean_squared_error: 3.6108
# Epoch 36/500
# 614/614 [==============================] - 0s 145us/sample - loss: 11.4541 - y1_output_loss: 4.1600 - y2_output_loss: 7.2091 - y1_output_root_mean_squared_error: 2.0486 - y2_output_root_mean_squared_error: 2.6940 - val_loss: 11.3501 - val_y1_output_loss: 2.7815 - val_y2_output_loss: 8.3287 - val_y1_output_root_mean_squared_error: 1.6671 - val_y2_output_root_mean_squared_error: 2.9276
# Epoch 37/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.1934 - y1_output_loss: 3.6710 - y2_output_loss: 6.4324 - y1_output_root_mean_squared_error: 1.9236 - y2_output_root_mean_squared_error: 2.5482 - val_loss: 7.5169 - val_y1_output_loss: 2.5252 - val_y2_output_loss: 4.8540 - val_y1_output_root_mean_squared_error: 1.5844 - val_y2_output_root_mean_squared_error: 2.2375
# Epoch 38/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.2784 - y1_output_loss: 3.0752 - y2_output_loss: 5.1354 - y1_output_root_mean_squared_error: 1.7609 - y2_output_root_mean_squared_error: 2.2754 - val_loss: 10.0619 - val_y1_output_loss: 3.2466 - val_y2_output_loss: 6.5903 - val_y1_output_root_mean_squared_error: 1.8021 - val_y2_output_root_mean_squared_error: 2.6104
# Epoch 39/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.1892 - y1_output_loss: 3.9549 - y2_output_loss: 7.1872 - y1_output_root_mean_squared_error: 1.9953 - y2_output_root_mean_squared_error: 2.6848 - val_loss: 8.4096 - val_y1_output_loss: 2.8065 - val_y2_output_loss: 5.4626 - val_y1_output_root_mean_squared_error: 1.6706 - val_y2_output_root_mean_squared_error: 2.3704
# Epoch 40/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.4129 - y1_output_loss: 3.2095 - y2_output_loss: 6.1821 - y1_output_root_mean_squared_error: 1.7877 - y2_output_root_mean_squared_error: 2.4934 - val_loss: 12.6879 - val_y1_output_loss: 4.3916 - val_y2_output_loss: 8.1560 - val_y1_output_root_mean_squared_error: 2.0700 - val_y2_output_root_mean_squared_error: 2.8988
# Epoch 41/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.1828 - y1_output_loss: 3.9381 - y2_output_loss: 8.1405 - y1_output_root_mean_squared_error: 1.9911 - y2_output_root_mean_squared_error: 2.8668 - val_loss: 6.5977 - val_y1_output_loss: 2.0116 - val_y2_output_loss: 4.5280 - val_y1_output_root_mean_squared_error: 1.4330 - val_y2_output_root_mean_squared_error: 2.1317
# Epoch 42/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.3761 - y1_output_loss: 2.9834 - y2_output_loss: 6.3074 - y1_output_root_mean_squared_error: 1.7350 - y2_output_root_mean_squared_error: 2.5231 - val_loss: 17.3593 - val_y1_output_loss: 6.1123 - val_y2_output_loss: 11.1311 - val_y1_output_root_mean_squared_error: 2.4431 - val_y2_output_root_mean_squared_error: 3.3750
# Epoch 43/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.0497 - y1_output_loss: 3.5139 - y2_output_loss: 7.4457 - y1_output_root_mean_squared_error: 1.8834 - y2_output_root_mean_squared_error: 2.7391 - val_loss: 7.8742 - val_y1_output_loss: 2.2438 - val_y2_output_loss: 5.6246 - val_y1_output_root_mean_squared_error: 1.5131 - val_y2_output_root_mean_squared_error: 2.3632
# Epoch 44/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.8964 - y1_output_loss: 3.9638 - y2_output_loss: 8.8141 - y1_output_root_mean_squared_error: 1.9999 - y2_output_root_mean_squared_error: 2.9828 - val_loss: 7.8899 - val_y1_output_loss: 2.4879 - val_y2_output_loss: 5.4475 - val_y1_output_root_mean_squared_error: 1.5818 - val_y2_output_root_mean_squared_error: 2.3212
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7405 - y1_output_loss: 2.8435 - y2_output_loss: 5.0017 - y1_output_root_mean_squared_error: 1.6756 - y2_output_root_mean_squared_error: 2.2210 - val_loss: 29.5335 - val_y1_output_loss: 8.7241 - val_y2_output_loss: 21.8130 - val_y1_output_root_mean_squared_error: 2.9296 - val_y2_output_root_mean_squared_error: 4.5772
# Epoch 46/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.2180 - y1_output_loss: 2.8885 - y2_output_loss: 6.3816 - y1_output_root_mean_squared_error: 1.7037 - y2_output_root_mean_squared_error: 2.5130 - val_loss: 23.5191 - val_y1_output_loss: 4.5589 - val_y2_output_loss: 18.9640 - val_y1_output_root_mean_squared_error: 2.0933 - val_y2_output_root_mean_squared_error: 4.3746
# Epoch 47/500
# 614/614 [==============================] - 0s 139us/sample - loss: 7.6953 - y1_output_loss: 2.5427 - y2_output_loss: 5.1077 - y1_output_root_mean_squared_error: 1.5951 - y2_output_root_mean_squared_error: 2.2696 - val_loss: 6.0463 - val_y1_output_loss: 1.7670 - val_y2_output_loss: 4.1744 - val_y1_output_root_mean_squared_error: 1.3438 - val_y2_output_root_mean_squared_error: 2.0593
# Epoch 48/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.4990 - y1_output_loss: 2.4059 - y2_output_loss: 5.0948 - y1_output_root_mean_squared_error: 1.5483 - y2_output_root_mean_squared_error: 2.2587 - val_loss: 11.1961 - val_y1_output_loss: 3.5375 - val_y2_output_loss: 7.4269 - val_y1_output_root_mean_squared_error: 1.8702 - val_y2_output_root_mean_squared_error: 2.7746
# Epoch 49/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.1704 - y1_output_loss: 2.1890 - y2_output_loss: 4.9327 - y1_output_root_mean_squared_error: 1.4866 - y2_output_root_mean_squared_error: 2.2272 - val_loss: 6.2583 - val_y1_output_loss: 1.6319 - val_y2_output_loss: 4.6162 - val_y1_output_root_mean_squared_error: 1.2855 - val_y2_output_root_mean_squared_error: 2.1461
# Epoch 50/500
# 614/614 [==============================] - 0s 375us/sample - loss: 6.7977 - y1_output_loss: 2.1963 - y2_output_loss: 4.5435 - y1_output_root_mean_squared_error: 1.4872 - y2_output_root_mean_squared_error: 2.1415 - val_loss: 7.1816 - val_y1_output_loss: 2.5271 - val_y2_output_loss: 4.5203 - val_y1_output_root_mean_squared_error: 1.5881 - val_y2_output_root_mean_squared_error: 2.1586
# Epoch 51/500
# 614/614 [==============================] - 0s 199us/sample - loss: 7.6923 - y1_output_loss: 2.3617 - y2_output_loss: 5.3320 - y1_output_root_mean_squared_error: 1.5375 - y2_output_root_mean_squared_error: 2.3084 - val_loss: 12.6652 - val_y1_output_loss: 3.2873 - val_y2_output_loss: 9.0862 - val_y1_output_root_mean_squared_error: 1.8098 - val_y2_output_root_mean_squared_error: 3.0643
# Epoch 52/500
# 614/614 [==============================] - 0s 184us/sample - loss: 7.5948 - y1_output_loss: 2.1825 - y2_output_loss: 5.3543 - y1_output_root_mean_squared_error: 1.4815 - y2_output_root_mean_squared_error: 2.3238 - val_loss: 6.4942 - val_y1_output_loss: 1.7191 - val_y2_output_loss: 4.8247 - val_y1_output_root_mean_squared_error: 1.3287 - val_y2_output_root_mean_squared_error: 2.1746
# Epoch 53/500
# 614/614 [==============================] - 0s 220us/sample - loss: 5.8833 - y1_output_loss: 1.9962 - y2_output_loss: 3.9436 - y1_output_root_mean_squared_error: 1.4035 - y2_output_root_mean_squared_error: 1.9783 - val_loss: 9.6290 - val_y1_output_loss: 3.1307 - val_y2_output_loss: 6.9118 - val_y1_output_root_mean_squared_error: 1.7581 - val_y2_output_root_mean_squared_error: 2.5570
# Epoch 54/500
# 614/614 [==============================] - 0s 193us/sample - loss: 6.8702 - y1_output_loss: 1.9496 - y2_output_loss: 4.8867 - y1_output_root_mean_squared_error: 1.3926 - y2_output_root_mean_squared_error: 2.2205 - val_loss: 5.6236 - val_y1_output_loss: 1.4722 - val_y2_output_loss: 4.0409 - val_y1_output_root_mean_squared_error: 1.2158 - val_y2_output_root_mean_squared_error: 2.0361
# Epoch 55/500
# 614/614 [==============================] - 0s 175us/sample - loss: 6.6152 - y1_output_loss: 1.8328 - y2_output_loss: 4.8090 - y1_output_root_mean_squared_error: 1.3585 - y2_output_root_mean_squared_error: 2.1839 - val_loss: 16.5609 - val_y1_output_loss: 6.0038 - val_y2_output_loss: 10.4009 - val_y1_output_root_mean_squared_error: 2.4350 - val_y2_output_root_mean_squared_error: 3.2606
# Epoch 56/500
# 614/614 [==============================] - 0s 178us/sample - loss: 7.3866 - y1_output_loss: 2.0291 - y2_output_loss: 5.4092 - y1_output_root_mean_squared_error: 1.4302 - y2_output_root_mean_squared_error: 2.3111 - val_loss: 12.9306 - val_y1_output_loss: 1.7425 - val_y2_output_loss: 11.5608 - val_y1_output_root_mean_squared_error: 1.3439 - val_y2_output_root_mean_squared_error: 3.3353
# Epoch 57/500
# 614/614 [==============================] - 0s 183us/sample - loss: 6.0498 - y1_output_loss: 1.7114 - y2_output_loss: 4.4125 - y1_output_root_mean_squared_error: 1.3085 - y2_output_root_mean_squared_error: 2.0827 - val_loss: 20.9332 - val_y1_output_loss: 4.2894 - val_y2_output_loss: 16.9260 - val_y1_output_root_mean_squared_error: 2.0949 - val_y2_output_root_mean_squared_error: 4.0675
# Epoch 58/500
# 614/614 [==============================] - 0s 172us/sample - loss: 7.1817 - y1_output_loss: 2.0707 - y2_output_loss: 5.1087 - y1_output_root_mean_squared_error: 1.4422 - y2_output_root_mean_squared_error: 2.2587 - val_loss: 18.0813 - val_y1_output_loss: 3.5516 - val_y2_output_loss: 14.5526 - val_y1_output_root_mean_squared_error: 1.8444 - val_y2_output_root_mean_squared_error: 3.8314
# Epoch 59/500
# 614/614 [==============================] - 0s 246us/sample - loss: 5.1669 - y1_output_loss: 1.5979 - y2_output_loss: 3.5481 - y1_output_root_mean_squared_error: 1.2619 - y2_output_root_mean_squared_error: 1.8907 - val_loss: 5.8920 - val_y1_output_loss: 1.6865 - val_y2_output_loss: 4.1029 - val_y1_output_root_mean_squared_error: 1.3025 - val_y2_output_root_mean_squared_error: 2.0483
# Epoch 60/500
# 614/614 [==============================] - 0s 193us/sample - loss: 5.5963 - y1_output_loss: 1.6538 - y2_output_loss: 3.9380 - y1_output_root_mean_squared_error: 1.2838 - y2_output_root_mean_squared_error: 1.9870 - val_loss: 7.4626 - val_y1_output_loss: 2.1911 - val_y2_output_loss: 5.6401 - val_y1_output_root_mean_squared_error: 1.4581 - val_y2_output_root_mean_squared_error: 2.3101
# Epoch 61/500
# 614/614 [==============================] - 0s 185us/sample - loss: 5.9950 - y1_output_loss: 1.7550 - y2_output_loss: 4.2710 - y1_output_root_mean_squared_error: 1.3211 - y2_output_root_mean_squared_error: 2.0615 - val_loss: 5.1889 - val_y1_output_loss: 1.4374 - val_y2_output_loss: 3.7690 - val_y1_output_root_mean_squared_error: 1.2054 - val_y2_output_root_mean_squared_error: 1.9329
# Epoch 62/500
# 614/614 [==============================] - 0s 185us/sample - loss: 6.9769 - y1_output_loss: 1.9911 - y2_output_loss: 5.0034 - y1_output_root_mean_squared_error: 1.4046 - y2_output_root_mean_squared_error: 2.2370 - val_loss: 8.1339 - val_y1_output_loss: 1.6704 - val_y2_output_loss: 6.7777 - val_y1_output_root_mean_squared_error: 1.2959 - val_y2_output_root_mean_squared_error: 2.5406
# Epoch 63/500
# 614/614 [==============================] - 0s 241us/sample - loss: 6.0032 - y1_output_loss: 1.6028 - y2_output_loss: 4.3973 - y1_output_root_mean_squared_error: 1.2688 - y2_output_root_mean_squared_error: 2.0960 - val_loss: 6.1543 - val_y1_output_loss: 1.4044 - val_y2_output_loss: 4.9687 - val_y1_output_root_mean_squared_error: 1.2049 - val_y2_output_root_mean_squared_error: 2.1685
# Epoch 64/500
# 614/614 [==============================] - 0s 189us/sample - loss: 6.5365 - y1_output_loss: 1.7312 - y2_output_loss: 4.7672 - y1_output_root_mean_squared_error: 1.3184 - y2_output_root_mean_squared_error: 2.1905 - val_loss: 6.3329 - val_y1_output_loss: 1.9440 - val_y2_output_loss: 4.3640 - val_y1_output_root_mean_squared_error: 1.4105 - val_y2_output_root_mean_squared_error: 2.0841
# Epoch 65/500
# 614/614 [==============================] - 0s 179us/sample - loss: 6.3728 - y1_output_loss: 1.8295 - y2_output_loss: 4.5242 - y1_output_root_mean_squared_error: 1.3533 - y2_output_root_mean_squared_error: 2.1311 - val_loss: 4.6675 - val_y1_output_loss: 1.3320 - val_y2_output_loss: 3.3163 - val_y1_output_root_mean_squared_error: 1.1585 - val_y2_output_root_mean_squared_error: 1.8235
# Epoch 66/500
# 614/614 [==============================] - 0s 184us/sample - loss: 4.8417 - y1_output_loss: 1.4643 - y2_output_loss: 3.3435 - y1_output_root_mean_squared_error: 1.2133 - y2_output_root_mean_squared_error: 1.8356 - val_loss: 4.2157 - val_y1_output_loss: 0.8988 - val_y2_output_loss: 3.2537 - val_y1_output_root_mean_squared_error: 0.9548 - val_y2_output_root_mean_squared_error: 1.8177
# Epoch 67/500
# 614/614 [==============================] - 0s 188us/sample - loss: 5.7096 - y1_output_loss: 1.8152 - y2_output_loss: 3.9711 - y1_output_root_mean_squared_error: 1.3396 - y2_output_root_mean_squared_error: 1.9786 - val_loss: 12.7320 - val_y1_output_loss: 3.7657 - val_y2_output_loss: 8.6216 - val_y1_output_root_mean_squared_error: 1.9453 - val_y2_output_root_mean_squared_error: 2.9913
# Epoch 68/500
# 614/614 [==============================] - 0s 198us/sample - loss: 4.8877 - y1_output_loss: 1.3069 - y2_output_loss: 3.6329 - y1_output_root_mean_squared_error: 1.1448 - y2_output_root_mean_squared_error: 1.8913 - val_loss: 8.1378 - val_y1_output_loss: 1.5340 - val_y2_output_loss: 6.6673 - val_y1_output_root_mean_squared_error: 1.2581 - val_y2_output_root_mean_squared_error: 2.5603
# Epoch 69/500
# 614/614 [==============================] - 0s 188us/sample - loss: 6.6740 - y1_output_loss: 1.7214 - y2_output_loss: 4.9001 - y1_output_root_mean_squared_error: 1.3150 - y2_output_root_mean_squared_error: 2.2237 - val_loss: 4.1443 - val_y1_output_loss: 0.9771 - val_y2_output_loss: 3.1564 - val_y1_output_root_mean_squared_error: 1.0020 - val_y2_output_root_mean_squared_error: 1.7721
# Epoch 70/500
# 614/614 [==============================] - 0s 187us/sample - loss: 4.8460 - y1_output_loss: 1.3562 - y2_output_loss: 3.4474 - y1_output_root_mean_squared_error: 1.1692 - y2_output_root_mean_squared_error: 1.8652 - val_loss: 4.3555 - val_y1_output_loss: 0.9002 - val_y2_output_loss: 3.4028 - val_y1_output_root_mean_squared_error: 0.9583 - val_y2_output_root_mean_squared_error: 1.8539
# Epoch 71/500
# 614/614 [==============================] - 0s 158us/sample - loss: 5.1251 - y1_output_loss: 1.2594 - y2_output_loss: 3.8464 - y1_output_root_mean_squared_error: 1.1222 - y2_output_root_mean_squared_error: 1.9662 - val_loss: 6.0208 - val_y1_output_loss: 1.6610 - val_y2_output_loss: 4.2625 - val_y1_output_root_mean_squared_error: 1.2699 - val_y2_output_root_mean_squared_error: 2.0996
# Epoch 72/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.0650 - y1_output_loss: 1.0689 - y2_output_loss: 3.0266 - y1_output_root_mean_squared_error: 1.0267 - y2_output_root_mean_squared_error: 1.7352 - val_loss: 10.8286 - val_y1_output_loss: 2.5311 - val_y2_output_loss: 8.1130 - val_y1_output_root_mean_squared_error: 1.5772 - val_y2_output_root_mean_squared_error: 2.8881
# Epoch 73/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.0842 - y1_output_loss: 1.1360 - y2_output_loss: 2.9390 - y1_output_root_mean_squared_error: 1.0693 - y2_output_root_mean_squared_error: 1.7149 - val_loss: 5.8731 - val_y1_output_loss: 1.0180 - val_y2_output_loss: 5.1076 - val_y1_output_root_mean_squared_error: 1.0169 - val_y2_output_root_mean_squared_error: 2.1998
# Epoch 74/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6944 - y1_output_loss: 0.8950 - y2_output_loss: 2.7802 - y1_output_root_mean_squared_error: 0.9464 - y2_output_root_mean_squared_error: 1.6729 - val_loss: 3.8654 - val_y1_output_loss: 0.7901 - val_y2_output_loss: 3.0054 - val_y1_output_root_mean_squared_error: 0.9000 - val_y2_output_root_mean_squared_error: 1.7480
# Epoch 75/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.1181 - y1_output_loss: 1.0900 - y2_output_loss: 3.0036 - y1_output_root_mean_squared_error: 1.0440 - y2_output_root_mean_squared_error: 1.7401 - val_loss: 6.0832 - val_y1_output_loss: 1.7450 - val_y2_output_loss: 4.2495 - val_y1_output_root_mean_squared_error: 1.3205 - val_y2_output_root_mean_squared_error: 2.0831
# Epoch 76/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.9483 - y1_output_loss: 1.0548 - y2_output_loss: 2.8930 - y1_output_root_mean_squared_error: 1.0256 - y2_output_root_mean_squared_error: 1.7019 - val_loss: 3.8659 - val_y1_output_loss: 0.7270 - val_y2_output_loss: 3.0845 - val_y1_output_root_mean_squared_error: 0.8644 - val_y2_output_root_mean_squared_error: 1.7660
# Epoch 77/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.3756 - y1_output_loss: 1.1685 - y2_output_loss: 3.1809 - y1_output_root_mean_squared_error: 1.0812 - y2_output_root_mean_squared_error: 1.7907 - val_loss: 4.4666 - val_y1_output_loss: 0.8791 - val_y2_output_loss: 3.5159 - val_y1_output_root_mean_squared_error: 0.9441 - val_y2_output_root_mean_squared_error: 1.8909
# Epoch 78/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.2151 - y1_output_loss: 1.2658 - y2_output_loss: 3.9196 - y1_output_root_mean_squared_error: 1.1289 - y2_output_root_mean_squared_error: 1.9851 - val_loss: 4.8181 - val_y1_output_loss: 1.2385 - val_y2_output_loss: 3.6806 - val_y1_output_root_mean_squared_error: 1.1133 - val_y2_output_root_mean_squared_error: 1.8917
# Epoch 79/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.6510 - y1_output_loss: 1.1828 - y2_output_loss: 3.4313 - y1_output_root_mean_squared_error: 1.0923 - y2_output_root_mean_squared_error: 1.8595 - val_loss: 3.8300 - val_y1_output_loss: 0.8370 - val_y2_output_loss: 2.9551 - val_y1_output_root_mean_squared_error: 0.9160 - val_y2_output_root_mean_squared_error: 1.7294
# Epoch 80/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7811 - y1_output_loss: 0.9571 - y2_output_loss: 2.8354 - y1_output_root_mean_squared_error: 0.9796 - y2_output_root_mean_squared_error: 1.6797 - val_loss: 5.1039 - val_y1_output_loss: 1.1449 - val_y2_output_loss: 3.8691 - val_y1_output_root_mean_squared_error: 1.0655 - val_y2_output_root_mean_squared_error: 1.9921
# Epoch 81/500
# 614/614 [==============================] - 0s 149us/sample - loss: 4.5188 - y1_output_loss: 1.1964 - y2_output_loss: 3.3277 - y1_output_root_mean_squared_error: 1.0869 - y2_output_root_mean_squared_error: 1.8268 - val_loss: 6.4061 - val_y1_output_loss: 1.5118 - val_y2_output_loss: 5.0352 - val_y1_output_root_mean_squared_error: 1.2467 - val_y2_output_root_mean_squared_error: 2.2027
# Epoch 82/500
# 614/614 [==============================] - 0s 194us/sample - loss: 3.8429 - y1_output_loss: 1.0421 - y2_output_loss: 2.8369 - y1_output_root_mean_squared_error: 1.0194 - y2_output_root_mean_squared_error: 1.6745 - val_loss: 7.5486 - val_y1_output_loss: 1.6682 - val_y2_output_loss: 5.9925 - val_y1_output_root_mean_squared_error: 1.3148 - val_y2_output_root_mean_squared_error: 2.4125
# Epoch 83/500
# 614/614 [==============================] - 0s 184us/sample - loss: 3.3926 - y1_output_loss: 0.9040 - y2_output_loss: 2.4606 - y1_output_root_mean_squared_error: 0.9540 - y2_output_root_mean_squared_error: 1.5756 - val_loss: 3.3733 - val_y1_output_loss: 0.6313 - val_y2_output_loss: 2.7282 - val_y1_output_root_mean_squared_error: 0.7967 - val_y2_output_root_mean_squared_error: 1.6549
# Epoch 84/500
# 614/614 [==============================] - 0s 181us/sample - loss: 4.2679 - y1_output_loss: 0.9678 - y2_output_loss: 3.3368 - y1_output_root_mean_squared_error: 0.9824 - y2_output_root_mean_squared_error: 1.8173 - val_loss: 4.8726 - val_y1_output_loss: 1.5199 - val_y2_output_loss: 3.3344 - val_y1_output_root_mean_squared_error: 1.2478 - val_y2_output_root_mean_squared_error: 1.8209
# Epoch 85/500
# 614/614 [==============================] - 0s 234us/sample - loss: 5.9133 - y1_output_loss: 1.6360 - y2_output_loss: 4.2739 - y1_output_root_mean_squared_error: 1.2761 - y2_output_root_mean_squared_error: 2.0700 - val_loss: 4.5273 - val_y1_output_loss: 0.7029 - val_y2_output_loss: 3.9336 - val_y1_output_root_mean_squared_error: 0.8444 - val_y2_output_root_mean_squared_error: 1.9530
# Epoch 86/500
# 614/614 [==============================] - 0s 188us/sample - loss: 4.4243 - y1_output_loss: 1.0626 - y2_output_loss: 3.3298 - y1_output_root_mean_squared_error: 1.0345 - y2_output_root_mean_squared_error: 1.8314 - val_loss: 3.7024 - val_y1_output_loss: 0.6358 - val_y2_output_loss: 3.0830 - val_y1_output_root_mean_squared_error: 0.7972 - val_y2_output_root_mean_squared_error: 1.7512
# Epoch 87/500
# 614/614 [==============================] - 0s 189us/sample - loss: 3.5213 - y1_output_loss: 0.8186 - y2_output_loss: 2.7113 - y1_output_root_mean_squared_error: 0.9080 - y2_output_root_mean_squared_error: 1.6422 - val_loss: 6.3312 - val_y1_output_loss: 1.0905 - val_y2_output_loss: 5.6758 - val_y1_output_root_mean_squared_error: 1.0400 - val_y2_output_root_mean_squared_error: 2.2912
# Epoch 88/500
# 614/614 [==============================] - 0s 176us/sample - loss: 2.8111 - y1_output_loss: 0.6770 - y2_output_loss: 2.1335 - y1_output_root_mean_squared_error: 0.8247 - y2_output_root_mean_squared_error: 1.4598 - val_loss: 5.8845 - val_y1_output_loss: 1.1406 - val_y2_output_loss: 5.0169 - val_y1_output_root_mean_squared_error: 1.0753 - val_y2_output_root_mean_squared_error: 2.1745
# Epoch 89/500
# 614/614 [==============================] - 0s 184us/sample - loss: 3.4204 - y1_output_loss: 0.8996 - y2_output_loss: 2.5013 - y1_output_root_mean_squared_error: 0.9512 - y2_output_root_mean_squared_error: 1.5861 - val_loss: 6.3779 - val_y1_output_loss: 1.7875 - val_y2_output_loss: 4.6907 - val_y1_output_root_mean_squared_error: 1.2883 - val_y2_output_root_mean_squared_error: 2.1721
# Epoch 90/500
# 614/614 [==============================] - 0s 227us/sample - loss: 3.0118 - y1_output_loss: 0.8063 - y2_output_loss: 2.1950 - y1_output_root_mean_squared_error: 0.9013 - y2_output_root_mean_squared_error: 1.4831 - val_loss: 4.4382 - val_y1_output_loss: 1.1179 - val_y2_output_loss: 3.3150 - val_y1_output_root_mean_squared_error: 1.0587 - val_y2_output_root_mean_squared_error: 1.8214
# Epoch 91/500
# 614/614 [==============================] - 0s 186us/sample - loss: 3.2904 - y1_output_loss: 0.7888 - y2_output_loss: 2.4747 - y1_output_root_mean_squared_error: 0.8914 - y2_output_root_mean_squared_error: 1.5798 - val_loss: 4.4696 - val_y1_output_loss: 1.0368 - val_y2_output_loss: 3.3580 - val_y1_output_root_mean_squared_error: 1.0108 - val_y2_output_root_mean_squared_error: 1.8568
# Epoch 92/500
# 614/614 [==============================] - 0s 172us/sample - loss: 3.4656 - y1_output_loss: 0.8292 - y2_output_loss: 2.6127 - y1_output_root_mean_squared_error: 0.9146 - y2_output_root_mean_squared_error: 1.6214 - val_loss: 4.8290 - val_y1_output_loss: 0.8674 - val_y2_output_loss: 4.1882 - val_y1_output_root_mean_squared_error: 0.9431 - val_y2_output_root_mean_squared_error: 1.9848
# Epoch 93/500
# 614/614 [==============================] - 0s 187us/sample - loss: 3.5075 - y1_output_loss: 0.8526 - y2_output_loss: 2.6384 - y1_output_root_mean_squared_error: 0.9236 - y2_output_root_mean_squared_error: 1.6292 - val_loss: 5.2566 - val_y1_output_loss: 0.9032 - val_y2_output_loss: 4.6487 - val_y1_output_root_mean_squared_error: 0.9556 - val_y2_output_root_mean_squared_error: 2.0841
# Epoch 94/500
# 614/614 [==============================] - 0s 492us/sample - loss: 3.3195 - y1_output_loss: 0.7718 - y2_output_loss: 2.5274 - y1_output_root_mean_squared_error: 0.8828 - y2_output_root_mean_squared_error: 1.5938 - val_loss: 3.6996 - val_y1_output_loss: 0.5666 - val_y2_output_loss: 3.3056 - val_y1_output_root_mean_squared_error: 0.7540 - val_y2_output_root_mean_squared_error: 1.7695
# Epoch 95/500
# 614/614 [==============================] - 0s 364us/sample - loss: 3.1021 - y1_output_loss: 0.8666 - y2_output_loss: 2.2251 - y1_output_root_mean_squared_error: 0.9331 - y2_output_root_mean_squared_error: 1.4938 - val_loss: 9.4699 - val_y1_output_loss: 1.9762 - val_y2_output_loss: 7.3361 - val_y1_output_root_mean_squared_error: 1.3983 - val_y2_output_root_mean_squared_error: 2.7413
# Epoch 96/500
# 614/614 [==============================] - 0s 626us/sample - loss: 3.5935 - y1_output_loss: 0.9130 - y2_output_loss: 2.7121 - y1_output_root_mean_squared_error: 0.9562 - y2_output_root_mean_squared_error: 1.6368 - val_loss: 12.9589 - val_y1_output_loss: 3.4662 - val_y2_output_loss: 9.7338 - val_y1_output_root_mean_squared_error: 1.7979 - val_y2_output_root_mean_squared_error: 3.1187
# Epoch 97/500
# 614/614 [==============================] - 0s 518us/sample - loss: 3.6604 - y1_output_loss: 1.0668 - y2_output_loss: 2.5700 - y1_output_root_mean_squared_error: 1.0368 - y2_output_root_mean_squared_error: 1.6079 - val_loss: 3.4244 - val_y1_output_loss: 0.7165 - val_y2_output_loss: 2.6810 - val_y1_output_root_mean_squared_error: 0.8517 - val_y2_output_root_mean_squared_error: 1.6429
# Epoch 98/500
# 614/614 [==============================] - 0s 631us/sample - loss: 9.4702 - y1_output_loss: 2.9319 - y2_output_loss: 6.5059 - y1_output_root_mean_squared_error: 1.7162 - y2_output_root_mean_squared_error: 2.5544 - val_loss: 9.3578 - val_y1_output_loss: 2.8228 - val_y2_output_loss: 6.5772 - val_y1_output_root_mean_squared_error: 1.6294 - val_y2_output_root_mean_squared_error: 2.5890
# Epoch 99/500
# 614/614 [==============================] - 0s 626us/sample - loss: 3.2312 - y1_output_loss: 0.8358 - y2_output_loss: 2.3717 - y1_output_root_mean_squared_error: 0.9181 - y2_output_root_mean_squared_error: 1.5454 - val_loss: 5.4718 - val_y1_output_loss: 0.9748 - val_y2_output_loss: 4.4209 - val_y1_output_root_mean_squared_error: 0.9662 - val_y2_output_root_mean_squared_error: 2.1303
# Epoch 100/500
# 614/614 [==============================] - 0s 503us/sample - loss: 2.7548 - y1_output_loss: 0.5741 - y2_output_loss: 2.2032 - y1_output_root_mean_squared_error: 0.7606 - y2_output_root_mean_squared_error: 1.4752 - val_loss: 5.1866 - val_y1_output_loss: 0.6252 - val_y2_output_loss: 4.4251 - val_y1_output_root_mean_squared_error: 0.7944 - val_y2_output_root_mean_squared_error: 2.1344
# Epoch 101/500
# 614/614 [==============================] - 0s 514us/sample - loss: 2.7500 - y1_output_loss: 0.5682 - y2_output_loss: 2.1604 - y1_output_root_mean_squared_error: 0.7545 - y2_output_root_mean_squared_error: 1.4768 - val_loss: 2.7826 - val_y1_output_loss: 0.4366 - val_y2_output_loss: 2.4127 - val_y1_output_root_mean_squared_error: 0.6595 - val_y2_output_root_mean_squared_error: 1.5322
# Epoch 102/500
# 614/614 [==============================] - 0s 625us/sample - loss: 2.7968 - y1_output_loss: 0.6885 - y2_output_loss: 2.1216 - y1_output_root_mean_squared_error: 0.8335 - y2_output_root_mean_squared_error: 1.4499 - val_loss: 3.6587 - val_y1_output_loss: 0.5512 - val_y2_output_loss: 3.3091 - val_y1_output_root_mean_squared_error: 0.7532 - val_y2_output_root_mean_squared_error: 1.7582
# Epoch 103/500
# 614/614 [==============================] - 0s 508us/sample - loss: 2.3234 - y1_output_loss: 0.4753 - y2_output_loss: 1.8444 - y1_output_root_mean_squared_error: 0.6918 - y2_output_root_mean_squared_error: 1.3582 - val_loss: 3.6594 - val_y1_output_loss: 0.7176 - val_y2_output_loss: 3.0364 - val_y1_output_root_mean_squared_error: 0.8596 - val_y2_output_root_mean_squared_error: 1.7090
# Epoch 104/500
# 614/614 [==============================] - 0s 627us/sample - loss: 2.4580 - y1_output_loss: 0.5787 - y2_output_loss: 1.8970 - y1_output_root_mean_squared_error: 0.7502 - y2_output_root_mean_squared_error: 1.3767 - val_loss: 6.6044 - val_y1_output_loss: 3.3009 - val_y2_output_loss: 3.7325 - val_y1_output_root_mean_squared_error: 1.7752 - val_y2_output_root_mean_squared_error: 1.8582
# Epoch 105/500
# 614/614 [==============================] - 0s 630us/sample - loss: 2.7145 - y1_output_loss: 0.5972 - y2_output_loss: 2.0931 - y1_output_root_mean_squared_error: 0.7764 - y2_output_root_mean_squared_error: 1.4532 - val_loss: 2.8259 - val_y1_output_loss: 0.4263 - val_y2_output_loss: 2.4034 - val_y1_output_root_mean_squared_error: 0.6512 - val_y2_output_root_mean_squared_error: 1.5498
# Epoch 106/500
# 614/614 [==============================] - 0s 512us/sample - loss: 2.8756 - y1_output_loss: 0.7019 - y2_output_loss: 2.1573 - y1_output_root_mean_squared_error: 0.8396 - y2_output_root_mean_squared_error: 1.4733 - val_loss: 3.8257 - val_y1_output_loss: 0.8418 - val_y2_output_loss: 3.1658 - val_y1_output_root_mean_squared_error: 0.9292 - val_y2_output_root_mean_squared_error: 1.7211
# Epoch 107/500
# 614/614 [==============================] - 0s 503us/sample - loss: 2.0976 - y1_output_loss: 0.5390 - y2_output_loss: 1.5555 - y1_output_root_mean_squared_error: 0.7289 - y2_output_root_mean_squared_error: 1.2515 - val_loss: 3.4704 - val_y1_output_loss: 1.2929 - val_y2_output_loss: 2.2831 - val_y1_output_root_mean_squared_error: 1.1100 - val_y2_output_root_mean_squared_error: 1.4961
# Epoch 108/500
# 614/614 [==============================] - 0s 627us/sample - loss: 2.2221 - y1_output_loss: 0.5126 - y2_output_loss: 1.6981 - y1_output_root_mean_squared_error: 0.7162 - y2_output_root_mean_squared_error: 1.3074 - val_loss: 3.1991 - val_y1_output_loss: 0.6466 - val_y2_output_loss: 2.5392 - val_y1_output_root_mean_squared_error: 0.7978 - val_y2_output_root_mean_squared_error: 1.6008
# Epoch 109/500
# 614/614 [==============================] - 0s 509us/sample - loss: 2.3080 - y1_output_loss: 0.5029 - y2_output_loss: 1.7910 - y1_output_root_mean_squared_error: 0.7112 - y2_output_root_mean_squared_error: 1.3425 - val_loss: 2.9044 - val_y1_output_loss: 0.6676 - val_y2_output_loss: 2.3004 - val_y1_output_root_mean_squared_error: 0.8208 - val_y2_output_root_mean_squared_error: 1.4935
# Epoch 110/500
# 614/614 [==============================] - 0s 627us/sample - loss: 2.8402 - y1_output_loss: 0.6635 - y2_output_loss: 2.1757 - y1_output_root_mean_squared_error: 0.8070 - y2_output_root_mean_squared_error: 1.4795 - val_loss: 3.6093 - val_y1_output_loss: 0.7914 - val_y2_output_loss: 2.9188 - val_y1_output_root_mean_squared_error: 0.8833 - val_y2_output_root_mean_squared_error: 1.6820
# Epoch 111/500
# 614/614 [==============================] - 0s 508us/sample - loss: 2.3060 - y1_output_loss: 0.5340 - y2_output_loss: 1.7582 - y1_output_root_mean_squared_error: 0.7325 - y2_output_root_mean_squared_error: 1.3302 - val_loss: 5.3683 - val_y1_output_loss: 1.5419 - val_y2_output_loss: 4.1637 - val_y1_output_root_mean_squared_error: 1.2351 - val_y2_output_root_mean_squared_error: 1.9603
# Epoch 112/500
# 614/614 [==============================] - 0s 623us/sample - loss: 2.3568 - y1_output_loss: 0.5335 - y2_output_loss: 1.8116 - y1_output_root_mean_squared_error: 0.7338 - y2_output_root_mean_squared_error: 1.3485 - val_loss: 2.9209 - val_y1_output_loss: 0.4944 - val_y2_output_loss: 2.4575 - val_y1_output_root_mean_squared_error: 0.7018 - val_y2_output_root_mean_squared_error: 1.5583
# Epoch 113/500
# 614/614 [==============================] - 0s 523us/sample - loss: 2.0792 - y1_output_loss: 0.4579 - y2_output_loss: 1.6230 - y1_output_root_mean_squared_error: 0.6765 - y2_output_root_mean_squared_error: 1.2734 - val_loss: 3.1245 - val_y1_output_loss: 0.4019 - val_y2_output_loss: 2.9135 - val_y1_output_root_mean_squared_error: 0.6394 - val_y2_output_root_mean_squared_error: 1.6479
# Epoch 114/500
# 614/614 [==============================] - 0s 510us/sample - loss: 1.9560 - y1_output_loss: 0.5323 - y2_output_loss: 1.4082 - y1_output_root_mean_squared_error: 0.7314 - y2_output_root_mean_squared_error: 1.1921 - val_loss: 2.6305 - val_y1_output_loss: 0.4190 - val_y2_output_loss: 2.1934 - val_y1_output_root_mean_squared_error: 0.6450 - val_y2_output_root_mean_squared_error: 1.4881
# Epoch 115/500
# 614/614 [==============================] - 0s 505us/sample - loss: 2.4098 - y1_output_loss: 0.5429 - y2_output_loss: 1.8737 - y1_output_root_mean_squared_error: 0.7394 - y2_output_root_mean_squared_error: 1.3650 - val_loss: 4.2448 - val_y1_output_loss: 0.8497 - val_y2_output_loss: 3.5134 - val_y1_output_root_mean_squared_error: 0.9275 - val_y2_output_root_mean_squared_error: 1.8397
# Epoch 116/500
# 614/614 [==============================] - 0s 627us/sample - loss: 3.1956 - y1_output_loss: 0.8368 - y2_output_loss: 2.3470 - y1_output_root_mean_squared_error: 0.9175 - y2_output_root_mean_squared_error: 1.5342 - val_loss: 3.8971 - val_y1_output_loss: 0.5943 - val_y2_output_loss: 3.4612 - val_y1_output_root_mean_squared_error: 0.7794 - val_y2_output_root_mean_squared_error: 1.8137
# Epoch 117/500
# 614/614 [==============================] - 0s 503us/sample - loss: 2.2191 - y1_output_loss: 0.4694 - y2_output_loss: 1.7454 - y1_output_root_mean_squared_error: 0.6832 - y2_output_root_mean_squared_error: 1.3238 - val_loss: 6.5348 - val_y1_output_loss: 1.3671 - val_y2_output_loss: 5.1228 - val_y1_output_root_mean_squared_error: 1.1401 - val_y2_output_root_mean_squared_error: 2.2880
# Epoch 118/500
# 614/614 [==============================] - 0s 629us/sample - loss: 1.7478 - y1_output_loss: 0.3881 - y2_output_loss: 1.3805 - y1_output_root_mean_squared_error: 0.6213 - y2_output_root_mean_squared_error: 1.1670 - val_loss: 6.3668 - val_y1_output_loss: 0.8142 - val_y2_output_loss: 5.4371 - val_y1_output_root_mean_squared_error: 0.8937 - val_y2_output_root_mean_squared_error: 2.3597
# Epoch 119/500
# 614/614 [==============================] - 0s 502us/sample - loss: 2.3871 - y1_output_loss: 0.5069 - y2_output_loss: 1.8623 - y1_output_root_mean_squared_error: 0.7138 - y2_output_root_mean_squared_error: 1.3702 - val_loss: 2.8148 - val_y1_output_loss: 0.5285 - val_y2_output_loss: 2.2673 - val_y1_output_root_mean_squared_error: 0.7203 - val_y2_output_root_mean_squared_error: 1.5152
# Epoch 120/500
# 614/614 [==============================] - 0s 322us/sample - loss: 3.0925 - y1_output_loss: 0.7328 - y2_output_loss: 2.3460 - y1_output_root_mean_squared_error: 0.8590 - y2_output_root_mean_squared_error: 1.5345 - val_loss: 3.5093 - val_y1_output_loss: 0.7197 - val_y2_output_loss: 2.7603 - val_y1_output_root_mean_squared_error: 0.8450 - val_y2_output_root_mean_squared_error: 1.6719
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 514us/sample - loss: 0.3631 - y1_output_loss: 0.1359 - y2_output_loss: 0.2263 - y1_output_root_mean_squared_error: 0.3685 - y2_output_root_mean_squared_error: 0.4768 - val_loss: 1.0278 - val_y1_output_loss: 0.3132 - val_y2_output_loss: 0.6915 - val_y1_output_root_mean_squared_error: 0.5653 - val_y2_output_root_mean_squared_error: 0.8416
# Epoch 462/500
# 614/614 [==============================] - 0s 626us/sample - loss: 0.4122 - y1_output_loss: 0.1488 - y2_output_loss: 0.2649 - y1_output_root_mean_squared_error: 0.3846 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.3345 - val_y1_output_loss: 0.3682 - val_y2_output_loss: 0.9764 - val_y1_output_root_mean_squared_error: 0.6080 - val_y2_output_root_mean_squared_error: 0.9823
# Epoch 463/500
# 614/614 [==============================] - 0s 641us/sample - loss: 0.4427 - y1_output_loss: 0.1589 - y2_output_loss: 0.2820 - y1_output_root_mean_squared_error: 0.4006 - y2_output_root_mean_squared_error: 0.5313 - val_loss: 1.0818 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.8326 - val_y1_output_root_mean_squared_error: 0.4699 - val_y2_output_root_mean_squared_error: 0.9279
# Epoch 464/500
# 614/614 [==============================] - 0s 521us/sample - loss: 0.7227 - y1_output_loss: 0.1861 - y2_output_loss: 0.5388 - y1_output_root_mean_squared_error: 0.4323 - y2_output_root_mean_squared_error: 0.7320 - val_loss: 1.8072 - val_y1_output_loss: 0.1596 - val_y2_output_loss: 1.6115 - val_y1_output_root_mean_squared_error: 0.3874 - val_y2_output_root_mean_squared_error: 1.2873
# Epoch 465/500
# 614/614 [==============================] - 0s 631us/sample - loss: 0.5476 - y1_output_loss: 0.1713 - y2_output_loss: 0.3750 - y1_output_root_mean_squared_error: 0.4158 - y2_output_root_mean_squared_error: 0.6122 - val_loss: 1.2743 - val_y1_output_loss: 0.1734 - val_y2_output_loss: 1.0797 - val_y1_output_root_mean_squared_error: 0.4050 - val_y2_output_root_mean_squared_error: 1.0537
# Epoch 466/500
# 614/614 [==============================] - 0s 631us/sample - loss: 0.5645 - y1_output_loss: 0.1766 - y2_output_loss: 0.4280 - y1_output_root_mean_squared_error: 0.4137 - y2_output_root_mean_squared_error: 0.6272 - val_loss: 4.3354 - val_y1_output_loss: 0.7801 - val_y2_output_loss: 3.5592 - val_y1_output_root_mean_squared_error: 0.8612 - val_y2_output_root_mean_squared_error: 1.8957
# Epoch 467/500
# 614/614 [==============================] - 0s 522us/sample - loss: 0.9780 - y1_output_loss: 0.2435 - y2_output_loss: 0.7270 - y1_output_root_mean_squared_error: 0.4950 - y2_output_root_mean_squared_error: 0.8561 - val_loss: 1.0557 - val_y1_output_loss: 0.1757 - val_y2_output_loss: 0.8562 - val_y1_output_root_mean_squared_error: 0.4137 - val_y2_output_root_mean_squared_error: 0.9405
# Epoch 468/500
# 614/614 [==============================] - 0s 630us/sample - loss: 0.6142 - y1_output_loss: 0.1701 - y2_output_loss: 0.4414 - y1_output_root_mean_squared_error: 0.4140 - y2_output_root_mean_squared_error: 0.6654 - val_loss: 0.8926 - val_y1_output_loss: 0.2148 - val_y2_output_loss: 0.6651 - val_y1_output_root_mean_squared_error: 0.4581 - val_y2_output_root_mean_squared_error: 0.8263
# Epoch 469/500
# 614/614 [==============================] - 0s 630us/sample - loss: 0.4475 - y1_output_loss: 0.1467 - y2_output_loss: 0.3011 - y1_output_root_mean_squared_error: 0.3812 - y2_output_root_mean_squared_error: 0.5497 - val_loss: 1.1677 - val_y1_output_loss: 0.3707 - val_y2_output_loss: 0.7957 - val_y1_output_root_mean_squared_error: 0.5869 - val_y2_output_root_mean_squared_error: 0.9073
# Epoch 470/500
# 614/614 [==============================] - 0s 496us/sample - loss: 0.4011 - y1_output_loss: 0.1513 - y2_output_loss: 0.2507 - y1_output_root_mean_squared_error: 0.3879 - y2_output_root_mean_squared_error: 0.5006 - val_loss: 1.1121 - val_y1_output_loss: 0.3350 - val_y2_output_loss: 0.7487 - val_y1_output_root_mean_squared_error: 0.5838 - val_y2_output_root_mean_squared_error: 0.8783
# Epoch 471/500
# 614/614 [==============================] - 0s 488us/sample - loss: 0.4598 - y1_output_loss: 0.1560 - y2_output_loss: 0.3048 - y1_output_root_mean_squared_error: 0.3951 - y2_output_root_mean_squared_error: 0.5511 - val_loss: 1.1103 - val_y1_output_loss: 0.2103 - val_y2_output_loss: 0.9104 - val_y1_output_root_mean_squared_error: 0.4576 - val_y2_output_root_mean_squared_error: 0.9492
# Epoch 472/500
# 614/614 [==============================] - 0s 513us/sample - loss: 0.5305 - y1_output_loss: 0.1721 - y2_output_loss: 0.3583 - y1_output_root_mean_squared_error: 0.4162 - y2_output_root_mean_squared_error: 0.5977 - val_loss: 1.1703 - val_y1_output_loss: 0.1854 - val_y2_output_loss: 0.9575 - val_y1_output_root_mean_squared_error: 0.4252 - val_y2_output_root_mean_squared_error: 0.9948
# Epoch 473/500
# 614/614 [==============================] - 0s 624us/sample - loss: 0.4672 - y1_output_loss: 0.1732 - y2_output_loss: 0.2923 - y1_output_root_mean_squared_error: 0.4163 - y2_output_root_mean_squared_error: 0.5422 - val_loss: 1.0902 - val_y1_output_loss: 0.2738 - val_y2_output_loss: 0.8053 - val_y1_output_root_mean_squared_error: 0.5311 - val_y2_output_root_mean_squared_error: 0.8990
# Epoch 474/500
# 614/614 [==============================] - 0s 516us/sample - loss: 0.5245 - y1_output_loss: 0.1748 - y2_output_loss: 0.3483 - y1_output_root_mean_squared_error: 0.4176 - y2_output_root_mean_squared_error: 0.5917 - val_loss: 1.1670 - val_y1_output_loss: 0.3977 - val_y2_output_loss: 0.7534 - val_y1_output_root_mean_squared_error: 0.6386 - val_y2_output_root_mean_squared_error: 0.8713
# Epoch 475/500
# 614/614 [==============================] - 0s 626us/sample - loss: 0.4703 - y1_output_loss: 0.1768 - y2_output_loss: 0.2897 - y1_output_root_mean_squared_error: 0.4222 - y2_output_root_mean_squared_error: 0.5404 - val_loss: 0.9621 - val_y1_output_loss: 0.2133 - val_y2_output_loss: 0.7440 - val_y1_output_root_mean_squared_error: 0.4399 - val_y2_output_root_mean_squared_error: 0.8767
# Epoch 476/500
# 614/614 [==============================] - 0s 511us/sample - loss: 0.3936 - y1_output_loss: 0.1387 - y2_output_loss: 0.2519 - y1_output_root_mean_squared_error: 0.3741 - y2_output_root_mean_squared_error: 0.5036 - val_loss: 0.8867 - val_y1_output_loss: 0.1974 - val_y2_output_loss: 0.6799 - val_y1_output_root_mean_squared_error: 0.4329 - val_y2_output_root_mean_squared_error: 0.8362
# Epoch 477/500
# 614/614 [==============================] - 0s 633us/sample - loss: 0.5969 - y1_output_loss: 0.1608 - y2_output_loss: 0.4331 - y1_output_root_mean_squared_error: 0.4029 - y2_output_root_mean_squared_error: 0.6592 - val_loss: 1.1629 - val_y1_output_loss: 0.1488 - val_y2_output_loss: 0.9912 - val_y1_output_root_mean_squared_error: 0.3788 - val_y2_output_root_mean_squared_error: 1.0097
# Epoch 478/500
# 614/614 [==============================] - 0s 631us/sample - loss: 0.5502 - y1_output_loss: 0.2078 - y2_output_loss: 0.3405 - y1_output_root_mean_squared_error: 0.4559 - y2_output_root_mean_squared_error: 0.5852 - val_loss: 0.8828 - val_y1_output_loss: 0.2188 - val_y2_output_loss: 0.6562 - val_y1_output_root_mean_squared_error: 0.4531 - val_y2_output_root_mean_squared_error: 0.8231
# Epoch 479/500
# 614/614 [==============================] - 0s 518us/sample - loss: 0.4433 - y1_output_loss: 0.1446 - y2_output_loss: 0.2947 - y1_output_root_mean_squared_error: 0.3819 - y2_output_root_mean_squared_error: 0.5454 - val_loss: 0.9384 - val_y1_output_loss: 0.2288 - val_y2_output_loss: 0.7006 - val_y1_output_root_mean_squared_error: 0.4627 - val_y2_output_root_mean_squared_error: 0.8511
# Epoch 480/500
# 614/614 [==============================] - 0s 628us/sample - loss: 0.4263 - y1_output_loss: 0.1466 - y2_output_loss: 0.2775 - y1_output_root_mean_squared_error: 0.3835 - y2_output_root_mean_squared_error: 0.5284 - val_loss: 0.9439 - val_y1_output_loss: 0.1587 - val_y2_output_loss: 0.7662 - val_y1_output_root_mean_squared_error: 0.3916 - val_y2_output_root_mean_squared_error: 0.8891
# Epoch 481/500
# 614/614 [==============================] - 0s 515us/sample - loss: 0.6014 - y1_output_loss: 0.1750 - y2_output_loss: 0.4294 - y1_output_root_mean_squared_error: 0.4164 - y2_output_root_mean_squared_error: 0.6543 - val_loss: 4.4210 - val_y1_output_loss: 1.1905 - val_y2_output_loss: 3.3467 - val_y1_output_root_mean_squared_error: 1.0470 - val_y2_output_root_mean_squared_error: 1.8234
# Epoch 482/500
# 614/614 [==============================] - 0s 634us/sample - loss: 0.6977 - y1_output_loss: 0.2325 - y2_output_loss: 0.4617 - y1_output_root_mean_squared_error: 0.4832 - y2_output_root_mean_squared_error: 0.6813 - val_loss: 1.0125 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.7931 - val_y1_output_root_mean_squared_error: 0.4556 - val_y2_output_root_mean_squared_error: 0.8972
# Epoch 483/500
# 614/614 [==============================] - 0s 631us/sample - loss: 0.4483 - y1_output_loss: 0.1572 - y2_output_loss: 0.2918 - y1_output_root_mean_squared_error: 0.3973 - y2_output_root_mean_squared_error: 0.5390 - val_loss: 1.5474 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 1.3265 - val_y1_output_root_mean_squared_error: 0.4307 - val_y2_output_root_mean_squared_error: 1.1670
# Epoch 484/500
# 614/614 [==============================] - 0s 507us/sample - loss: 0.5412 - y1_output_loss: 0.1612 - y2_output_loss: 0.3986 - y1_output_root_mean_squared_error: 0.3995 - y2_output_root_mean_squared_error: 0.6177 - val_loss: 6.4044 - val_y1_output_loss: 0.9543 - val_y2_output_loss: 5.4392 - val_y1_output_root_mean_squared_error: 0.9937 - val_y2_output_root_mean_squared_error: 2.3275
# Epoch 485/500
# 614/614 [==============================] - 0s 637us/sample - loss: 0.5760 - y1_output_loss: 0.2107 - y2_output_loss: 0.3739 - y1_output_root_mean_squared_error: 0.4477 - y2_output_root_mean_squared_error: 0.6128 - val_loss: 1.6433 - val_y1_output_loss: 0.4395 - val_y2_output_loss: 1.1994 - val_y1_output_root_mean_squared_error: 0.6492 - val_y2_output_root_mean_squared_error: 1.1054
# Epoch 486/500
# 614/614 [==============================] - 0s 640us/sample - loss: 0.4262 - y1_output_loss: 0.1549 - y2_output_loss: 0.2684 - y1_output_root_mean_squared_error: 0.3952 - y2_output_root_mean_squared_error: 0.5197 - val_loss: 1.0194 - val_y1_output_loss: 0.1779 - val_y2_output_loss: 0.8299 - val_y1_output_root_mean_squared_error: 0.4110 - val_y2_output_root_mean_squared_error: 0.9222
# Epoch 487/500
# 614/614 [==============================] - 0s 509us/sample - loss: 0.5907 - y1_output_loss: 0.1877 - y2_output_loss: 0.3988 - y1_output_root_mean_squared_error: 0.4348 - y2_output_root_mean_squared_error: 0.6338 - val_loss: 0.9132 - val_y1_output_loss: 0.1904 - val_y2_output_loss: 0.7070 - val_y1_output_root_mean_squared_error: 0.4325 - val_y2_output_root_mean_squared_error: 0.8521
# Epoch 488/500
# 614/614 [==============================] - 0s 639us/sample - loss: 0.6076 - y1_output_loss: 0.1878 - y2_output_loss: 0.4148 - y1_output_root_mean_squared_error: 0.4350 - y2_output_root_mean_squared_error: 0.6468 - val_loss: 1.0281 - val_y1_output_loss: 0.2033 - val_y2_output_loss: 0.8145 - val_y1_output_root_mean_squared_error: 0.4502 - val_y2_output_root_mean_squared_error: 0.9085
# Epoch 489/500
# 614/614 [==============================] - 0s 638us/sample - loss: 0.5923 - y1_output_loss: 0.1650 - y2_output_loss: 0.4246 - y1_output_root_mean_squared_error: 0.4074 - y2_output_root_mean_squared_error: 0.6529 - val_loss: 1.3091 - val_y1_output_loss: 0.3157 - val_y2_output_loss: 0.9884 - val_y1_output_root_mean_squared_error: 0.5710 - val_y2_output_root_mean_squared_error: 0.9915
# Epoch 490/500
# 614/614 [==============================] - 0s 519us/sample - loss: 0.3999 - y1_output_loss: 0.1466 - y2_output_loss: 0.2571 - y1_output_root_mean_squared_error: 0.3777 - y2_output_root_mean_squared_error: 0.5072 - val_loss: 1.0168 - val_y1_output_loss: 0.1716 - val_y2_output_loss: 0.8304 - val_y1_output_root_mean_squared_error: 0.4043 - val_y2_output_root_mean_squared_error: 0.9238
# Epoch 491/500
# 614/614 [==============================] - 0s 626us/sample - loss: 0.5447 - y1_output_loss: 0.1939 - y2_output_loss: 0.3627 - y1_output_root_mean_squared_error: 0.4326 - y2_output_root_mean_squared_error: 0.5980 - val_loss: 4.0799 - val_y1_output_loss: 0.7330 - val_y2_output_loss: 3.3773 - val_y1_output_root_mean_squared_error: 0.8671 - val_y2_output_root_mean_squared_error: 1.8243
# Epoch 492/500
# 614/614 [==============================] - 0s 514us/sample - loss: 0.7954 - y1_output_loss: 0.2119 - y2_output_loss: 0.5808 - y1_output_root_mean_squared_error: 0.4624 - y2_output_root_mean_squared_error: 0.7626 - val_loss: 1.4350 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 1.2414 - val_y1_output_root_mean_squared_error: 0.4403 - val_y2_output_root_mean_squared_error: 1.1141
# Epoch 493/500
# 614/614 [==============================] - 0s 630us/sample - loss: 0.3237 - y1_output_loss: 0.1165 - y2_output_loss: 0.2074 - y1_output_root_mean_squared_error: 0.3405 - y2_output_root_mean_squared_error: 0.4558 - val_loss: 1.2455 - val_y1_output_loss: 0.2478 - val_y2_output_loss: 0.9820 - val_y1_output_root_mean_squared_error: 0.4990 - val_y2_output_root_mean_squared_error: 0.9982
# Epoch 494/500
# 614/614 [==============================] - 0s 638us/sample - loss: 0.4470 - y1_output_loss: 0.1686 - y2_output_loss: 0.2777 - y1_output_root_mean_squared_error: 0.4103 - y2_output_root_mean_squared_error: 0.5279 - val_loss: 1.0269 - val_y1_output_loss: 0.2731 - val_y2_output_loss: 0.7375 - val_y1_output_root_mean_squared_error: 0.5260 - val_y2_output_root_mean_squared_error: 0.8662
# Epoch 495/500
# 614/614 [==============================] - 0s 522us/sample - loss: 0.4340 - y1_output_loss: 0.1425 - y2_output_loss: 0.2881 - y1_output_root_mean_squared_error: 0.3791 - y2_output_root_mean_squared_error: 0.5388 - val_loss: 0.9702 - val_y1_output_loss: 0.1834 - val_y2_output_loss: 0.7715 - val_y1_output_root_mean_squared_error: 0.4213 - val_y2_output_root_mean_squared_error: 0.8903
# Epoch 496/500
# 614/614 [==============================] - 0s 517us/sample - loss: 0.3328 - y1_output_loss: 0.1246 - y2_output_loss: 0.2080 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.4570 - val_loss: 1.3046 - val_y1_output_loss: 0.3095 - val_y2_output_loss: 0.9707 - val_y1_output_root_mean_squared_error: 0.5646 - val_y2_output_root_mean_squared_error: 0.9929
# Epoch 497/500
# 614/614 [==============================] - 0s 630us/sample - loss: 0.4905 - y1_output_loss: 0.1638 - y2_output_loss: 0.3290 - y1_output_root_mean_squared_error: 0.4016 - y2_output_root_mean_squared_error: 0.5737 - val_loss: 0.9323 - val_y1_output_loss: 0.2004 - val_y2_output_loss: 0.7241 - val_y1_output_root_mean_squared_error: 0.4364 - val_y2_output_root_mean_squared_error: 0.8613
# Epoch 498/500
# 614/614 [==============================] - 0s 518us/sample - loss: 0.4110 - y1_output_loss: 0.1415 - y2_output_loss: 0.2667 - y1_output_root_mean_squared_error: 0.3766 - y2_output_root_mean_squared_error: 0.5188 - val_loss: 0.9933 - val_y1_output_loss: 0.2170 - val_y2_output_loss: 0.7736 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.8907
# Epoch 499/500
# 614/614 [==============================] - 0s 616us/sample - loss: 0.4030 - y1_output_loss: 0.1389 - y2_output_loss: 0.2671 - y1_output_root_mean_squared_error: 0.3731 - y2_output_root_mean_squared_error: 0.5136 - val_loss: 2.2100 - val_y1_output_loss: 0.5331 - val_y2_output_loss: 1.7292 - val_y1_output_root_mean_squared_error: 0.6908 - val_y2_output_root_mean_squared_error: 1.3163
# Epoch 500/500
# 614/614 [==============================] - 0s 366us/sample - loss: 0.4054 - y1_output_loss: 0.1538 - y2_output_loss: 0.2513 - y1_output_root_mean_squared_error: 0.3935 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 1.3020 - val_y1_output_loss: 0.1721 - val_y2_output_loss: 1.1121 - val_y1_output_root_mean_squared_error: 0.4062 - val_y2_output_root_mean_squared_error: 1.0663

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 499us/sample - loss: 1.3020 - y1_output_loss: 0.1656 - y2_output_loss: 1.1570 - y1_output_root_mean_squared_error: 0.4062 - y2_output_root_mean_squared_error: 1.0663
# Loss = 1.3020349168158196, Y1_loss = 0.16556496918201447, Y1_mse = 0.4061928689479828, Y2_loss = 1.157010793685913, Y2_mse = 1.066321849822998

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
